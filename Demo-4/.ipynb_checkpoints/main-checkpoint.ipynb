# %% [raw]
# cryptography_tasks/
# ├── main.py
# ├── settings_manager.py
# ├── task_manager.py
# ├── gui.py
# ├── data/
# │   └── tasks_metadata.csv
# └── app_settings.json (создается автоматически)

# %%
import tkinter as tk
from gui import CryptographyApp

def main():
    root = tk.Tk()
    app = CryptographyApp(root)
    root.mainloop()

if __name__ == "__main__":
    main()
# Out:
# Настройки сохранены в: C:\Users\weron\JN\Demo-4\app_settings.json
